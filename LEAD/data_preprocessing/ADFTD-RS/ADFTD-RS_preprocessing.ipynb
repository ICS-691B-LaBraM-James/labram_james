# %%
import os
import json
import mne
import numpy as np
import pandas as pd
from scipy.signal import resample
import warnings
warnings.filterwarnings("ignore")

# %%
# multi-scale sampling rates
SAMPLE_RATE_LIST = [200, 100, 50]  # Hz

# fixed segment length in samples (timestamps)
SEG_LEN = 400  # number of time steps per segment
# overlap in samples (timestamps), not in seconds
OVERLAP = 200    # e.g. 200 means 50% overlap for SEG_LEN=400

assert 0 <= OVERLAP < SEG_LEN, "OVERLAP must be in [0, SEG_LEN)."

sub_folder_path = f"L{SEG_LEN}"
sub_folder_path
# Out:
# 'L400'

# %%
# root dir
root = 'ADFTD-RS/'

# participants file path
participants_path = os.path.join(root, 'participants.tsv')
participants = pd.read_csv(participants_path, sep='\t')
participants
# Out:
#    participant_id Gender  Age Group  MMSE
# 0         sub-001      F   57     A    16
# 1         sub-002      F   78     A    22
# 2         sub-003      M   70     A    14
# 3         sub-004      F   67     A    20
# 4         sub-005      M   70     A    22
# ..            ...    ...  ...   ...   ...
# 83        sub-084      F   71     F    24
# 84        sub-085      M   64     F    26
# 85        sub-086      M   49     F    26
# 86        sub-087      M   73     F    24
# 87        sub-088      M   55     F    24
#
# [88 rows x 5 columns]

# %%
# label mapping: diagnosis code -> label id
label_map = {'A': 1, 'F': 2, 'C': 0}

# build subject info: "sub-XXX" -> (label, pid)
sub_info = {}  # key: subject name, value: (label, pid)
for row in participants.itertuples(index=False):
    sub_name = row[0]          # e.g. 'sub-001'
    diag_code = row[3]         # e.g. 'A' / 'F' / 'C'
    pid = int(sub_name[-3:])   # convert '001' -> 1
    label = label_map[diag_code]
    sub_info[sub_name] = (label, pid)

len(sub_info), list(sub_info.items())[:5]
# Out:
# (88,
#  [('sub-001', (1, 1)),
#   ('sub-002', (1, 2)),
#   ('sub-003', (1, 3)),
#   ('sub-004', (1, 4)),
#   ('sub-005', (1, 5))])

# %% [markdown]
# ## Features

# %%
from collections import defaultdict

# derivatives root
derivatives_root = os.path.join(root, 'derivatives')
derivatives_root
# Out:
# 'ADFTD-RS/derivatives'

# %%
# Test for bad channels, sampling freq and shape
bad_channel_list, sampling_freq_list, data_shape_list = [], [], []
for sub in os.listdir(derivatives_root):
    if 'sub-' in sub:
        sub_path = os.path.join(derivatives_root, sub, 'eeg/')
        # print(sub_path)
        for file in os.listdir(sub_path):
            if '.set' in file:
                file_path = os.path.join(sub_path, file)
                raw = mne.io.read_raw_eeglab(file_path, preload=True)
                # get bad channels
                bad_channel = raw.info['bads']
                bad_channel_list.append(bad_channel)
                # get sampling frequency
                sampling_freq = raw.info['sfreq']
                sampling_freq_list.append(sampling_freq)
                # get eeg data
                data = raw.get_data()
                data_shape = data.shape
                data_shape_list.append(data_shape)

# %%
from collections import Counter

print(bad_channel_list)
print(data_shape_list[0])
print("Raw channel number counter:", Counter(i[0] for i in data_shape_list))
print("Raw sampling rate counter:", Counter(sampling_freq_list))
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]
# (19, 299900)
# Raw channel number counter: Counter({19: 88})
# Raw sampling rate counter: Counter({500.0: 88})

# %%
# Initialize common channel list
common_channels = []

# Loop through subject folders
for sub in os.listdir(derivatives_root):
    if 'sub-' in sub:
        sub_path = os.path.join(root, sub, 'eeg/')
        for file in os.listdir(sub_path):
            # Change: look for BrainVision .vhdr files
            if '.set' in file:
                file_path = os.path.join(sub_path, file)
                raw = mne.io.read_raw_eeglab(file_path, preload=True)
                current_channels = set(raw.info['ch_names'])

                if not common_channels:
                    common_channels = current_channels
                else:
                    common_channels &= current_channels  # Intersection

# Convert set to list
common_channels = list(common_channels)
# Print result
print(common_channels)
print("Common channels number: ", len(common_channels))
# Out:
# ['T4', 'F3', 'C4', 'O1', 'Fp2', 'T6', 'Fz', 'T3', 'P3', 'Cz', 'Fp1', 'F4', 'P4', 'O2', 'F8', 'C3', 'T5', 'Pz', 'F7']
# Common channels number:  19

# %%
def resample_time_series(data, original_fs, target_fs):
    """
    Resample each channel independently.
    data: (T_raw, C)
    return: (T_new, C)
    """
    T, C = data.shape
    new_length = int(T * target_fs / original_fs)
    resampled_data = np.zeros((new_length, C), dtype=np.float32)
    for i in range(C):
        # resample one channel
        resampled_data[:, i] = resample(data[:, i], new_length)
    return resampled_data


def compute_step(seg_len, overlap):
    """
    Compute sliding step (in samples) given segment length and overlap.
    """
    step = seg_len - overlap
    if step <= 0:
        raise ValueError(f"Invalid overlap={overlap}: step <= 0.")
    return step


def compute_num_segments(num_samples, seg_len, step):
    """
    Compute how many segments can be extracted from a sequence
    with given segment length and step.
    """
    if num_samples < seg_len:
        return 0
    return 1 + (num_samples - seg_len) // step

# %% [markdown]
# ## PASS 1: Find total number of segments across all subjects

# %%
subject_segment_counts = defaultdict(lambda: defaultdict(int))
N_total = 0
n_channels = len(common_channels)

# step (timestamps)
STEP = compute_step(SEG_LEN, OVERLAP)
print("SEG_LEN =", SEG_LEN, "OVERLAP =", OVERLAP, "STEP =", STEP)

for sub in sorted(os.listdir(derivatives_root)):
    if 'sub-' in sub:
        li_sub = []
        sub_path = os.path.join(derivatives_root, sub, 'eeg/')
        print(sub_path)

        print(f"[PASS 1] Subject: {sub}")

        for file in os.listdir(sub_path):
            if '.set' in file:
                file_path = os.path.join(sub_path, file)
                print("  reading header:", file_path)
                # only load metadata
                raw = mne.io.read_raw_eeglab(file_path, preload=False)
                original_fs = raw.info['sfreq']
                T_raw = raw.n_times
        
                for fs in SAMPLE_RATE_LIST:
                    # resampled length if each trial
                    T_res = int(T_raw * fs / original_fs)
                    # compute number of segments
                    n_seg = compute_num_segments(T_res, SEG_LEN, STEP)
                    subject_segment_counts[sub][fs] += n_seg
                    N_total += n_seg
                    print(f"fs={fs}Hz: T_res={T_res}, STEP={STEP}, n_seg={n_seg}")
        print("-------------------------------------\n")

print("\n===================================")
print("Total segments N_total =", N_total)
print("Channels =", n_channels)
print("===================================")

if N_total == 0:
    raise RuntimeError("No segments found. Please check SEG_LEN / OVERLAP.")
# Out:
# SEG_LEN = 400 OVERLAP = 200 STEP = 200
# ADFTD-RS/derivatives\sub-001\eeg/
# [PASS 1] Subject: sub-001
#   reading header: ADFTD-RS/derivatives\sub-001\eeg/sub-001_task-eyesclosed_eeg.set
# fs=200Hz: T_res=119960, STEP=200, n_seg=598
# fs=100Hz: T_res=59980, STEP=200, n_seg=298
# fs=50Hz: T_res=29990, STEP=200, n_seg=148
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-002\eeg/
# [PASS 1] Subject: sub-002
#   reading header: ADFTD-RS/derivatives\sub-002\eeg/sub-002_task-eyesclosed_eeg.set
# fs=200Hz: T_res=158620, STEP=200, n_seg=792
# fs=100Hz: T_res=79310, STEP=200, n_seg=395
# fs=50Hz: T_res=39655, STEP=200, n_seg=197
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-003\eeg/
# [PASS 1] Subject: sub-003
#   reading header: ADFTD-RS/derivatives\sub-003\eeg/sub-003_task-eyesclosed_eeg.set
# fs=200Hz: T_res=61220, STEP=200, n_seg=305
# fs=100Hz: T_res=30610, STEP=200, n_seg=152
# fs=50Hz: T_res=15305, STEP=200, n_seg=75
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-004\eeg/
# [PASS 1] Subject: sub-004
#   reading header: ADFTD-RS/derivatives\sub-004\eeg/sub-004_task-eyesclosed_eeg.set
# fs=200Hz: T_res=141220, STEP=200, n_seg=705
# fs=100Hz: T_res=70610, STEP=200, n_seg=352
# fs=50Hz: T_res=35305, STEP=200, n_seg=175
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-005\eeg/
# [PASS 1] Subject: sub-005
#   reading header: ADFTD-RS/derivatives\sub-005\eeg/sub-005_task-eyesclosed_eeg.set
# fs=200Hz: T_res=160820, STEP=200, n_seg=803
# fs=100Hz: T_res=80410, STEP=200, n_seg=401
# fs=50Hz: T_res=40205, STEP=200, n_seg=200
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-006\eeg/
# [PASS 1] Subject: sub-006
#   reading header: ADFTD-RS/derivatives\sub-006\eeg/sub-006_task-eyesclosed_eeg.set
# fs=200Hz: T_res=126480, STEP=200, n_seg=631
# fs=100Hz: T_res=63240, STEP=200, n_seg=315
# fs=50Hz: T_res=31620, STEP=200, n_seg=157
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-007\eeg/
# [PASS 1] Subject: sub-007
#   reading header: ADFTD-RS/derivatives\sub-007\eeg/sub-007_task-eyesclosed_eeg.set
# fs=200Hz: T_res=153284, STEP=200, n_seg=765
# fs=100Hz: T_res=76642, STEP=200, n_seg=382
# fs=50Hz: T_res=38321, STEP=200, n_seg=190
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-008\eeg/
# [PASS 1] Subject: sub-008
#   reading header: ADFTD-RS/derivatives\sub-008\eeg/sub-008_task-eyesclosed_eeg.set
# fs=200Hz: T_res=158680, STEP=200, n_seg=792
# fs=100Hz: T_res=79340, STEP=200, n_seg=395
# fs=50Hz: T_res=39670, STEP=200, n_seg=197
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-009\eeg/
# [PASS 1] Subject: sub-009
#   reading header: ADFTD-RS/derivatives\sub-009\eeg/sub-009_task-eyesclosed_eeg.set
# fs=200Hz: T_res=122520, STEP=200, n_seg=611
# fs=100Hz: T_res=61260, STEP=200, n_seg=305
# fs=50Hz: T_res=30630, STEP=200, n_seg=152
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-010\eeg/
# [PASS 1] Subject: sub-010
#   reading header: ADFTD-RS/derivatives\sub-010\eeg/sub-010_task-eyesclosed_eeg.set
# fs=200Hz: T_res=256344, STEP=200, n_seg=1280
# fs=100Hz: T_res=128172, STEP=200, n_seg=639
# fs=50Hz: T_res=64086, STEP=200, n_seg=319
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-011\eeg/
# [PASS 1] Subject: sub-011
#   reading header: ADFTD-RS/derivatives\sub-011\eeg/sub-011_task-eyesclosed_eeg.set
# fs=200Hz: T_res=153984, STEP=200, n_seg=768
# fs=100Hz: T_res=76992, STEP=200, n_seg=383
# fs=50Hz: T_res=38496, STEP=200, n_seg=191
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-012\eeg/
# [PASS 1] Subject: sub-012
#   reading header: ADFTD-RS/derivatives\sub-012\eeg/sub-012_task-eyesclosed_eeg.set
# fs=200Hz: T_res=176704, STEP=200, n_seg=882
# fs=100Hz: T_res=88352, STEP=200, n_seg=440
# fs=50Hz: T_res=44176, STEP=200, n_seg=219
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-013\eeg/
# [PASS 1] Subject: sub-013
#   reading header: ADFTD-RS/derivatives\sub-013\eeg/sub-013_task-eyesclosed_eeg.set
# fs=200Hz: T_res=167620, STEP=200, n_seg=837
# fs=100Hz: T_res=83810, STEP=200, n_seg=418
# fs=50Hz: T_res=41905, STEP=200, n_seg=208
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-014\eeg/
# [PASS 1] Subject: sub-014
#   reading header: ADFTD-RS/derivatives\sub-014\eeg/sub-014_task-eyesclosed_eeg.set
# fs=200Hz: T_res=186888, STEP=200, n_seg=933
# fs=100Hz: T_res=93444, STEP=200, n_seg=466
# fs=50Hz: T_res=46722, STEP=200, n_seg=232
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-015\eeg/
# [PASS 1] Subject: sub-015
#   reading header: ADFTD-RS/derivatives\sub-015\eeg/sub-015_task-eyesclosed_eeg.set
# fs=200Hz: T_res=180276, STEP=200, n_seg=900
# fs=100Hz: T_res=90138, STEP=200, n_seg=449
# fs=50Hz: T_res=45069, STEP=200, n_seg=224
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-016\eeg/
# [PASS 1] Subject: sub-016
#   reading header: ADFTD-RS/derivatives\sub-016\eeg/sub-016_task-eyesclosed_eeg.set
# fs=200Hz: T_res=194472, STEP=200, n_seg=971
# fs=100Hz: T_res=97236, STEP=200, n_seg=485
# fs=50Hz: T_res=48618, STEP=200, n_seg=242
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-017\eeg/
# [PASS 1] Subject: sub-017
#   reading header: ADFTD-RS/derivatives\sub-017\eeg/sub-017_task-eyesclosed_eeg.set
# fs=200Hz: T_res=168680, STEP=200, n_seg=842
# fs=100Hz: T_res=84340, STEP=200, n_seg=420
# fs=50Hz: T_res=42170, STEP=200, n_seg=209
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-018\eeg/
# [PASS 1] Subject: sub-018
#   reading header: ADFTD-RS/derivatives\sub-018\eeg/sub-018_task-eyesclosed_eeg.set
# fs=200Hz: T_res=169020, STEP=200, n_seg=844
# fs=100Hz: T_res=84510, STEP=200, n_seg=421
# fs=50Hz: T_res=42255, STEP=200, n_seg=210
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-019\eeg/
# [PASS 1] Subject: sub-019
#   reading header: ADFTD-RS/derivatives\sub-019\eeg/sub-019_task-eyesclosed_eeg.set
# fs=200Hz: T_res=183724, STEP=200, n_seg=917
# fs=100Hz: T_res=91862, STEP=200, n_seg=458
# fs=50Hz: T_res=45931, STEP=200, n_seg=228
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-020\eeg/
# [PASS 1] Subject: sub-020
#   reading header: ADFTD-RS/derivatives\sub-020\eeg/sub-020_task-eyesclosed_eeg.set
# fs=200Hz: T_res=173860, STEP=200, n_seg=868
# fs=100Hz: T_res=86930, STEP=200, n_seg=433
# fs=50Hz: T_res=43465, STEP=200, n_seg=216
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-021\eeg/
# [PASS 1] Subject: sub-021
#   reading header: ADFTD-RS/derivatives\sub-021\eeg/sub-021_task-eyesclosed_eeg.set
# fs=200Hz: T_res=184056, STEP=200, n_seg=919
# fs=100Hz: T_res=92028, STEP=200, n_seg=459
# fs=50Hz: T_res=46014, STEP=200, n_seg=229
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-022\eeg/
# [PASS 1] Subject: sub-022
#   reading header: ADFTD-RS/derivatives\sub-022\eeg/sub-022_task-eyesclosed_eeg.set
# fs=200Hz: T_res=164384, STEP=200, n_seg=820
# fs=100Hz: T_res=82192, STEP=200, n_seg=409
# fs=50Hz: T_res=41096, STEP=200, n_seg=204
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-023\eeg/
# [PASS 1] Subject: sub-023
#   reading header: ADFTD-RS/derivatives\sub-023\eeg/sub-023_task-eyesclosed_eeg.set
# fs=200Hz: T_res=166948, STEP=200, n_seg=833
# fs=100Hz: T_res=83474, STEP=200, n_seg=416
# fs=50Hz: T_res=41737, STEP=200, n_seg=207
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-024\eeg/
# [PASS 1] Subject: sub-024
#   reading header: ADFTD-RS/derivatives\sub-024\eeg/sub-024_task-eyesclosed_eeg.set
# fs=200Hz: T_res=151960, STEP=200, n_seg=758
# fs=100Hz: T_res=75980, STEP=200, n_seg=378
# fs=50Hz: T_res=37990, STEP=200, n_seg=188
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-025\eeg/
# [PASS 1] Subject: sub-025
#   reading header: ADFTD-RS/derivatives\sub-025\eeg/sub-025_task-eyesclosed_eeg.set
# fs=200Hz: T_res=136872, STEP=200, n_seg=683
# fs=100Hz: T_res=68436, STEP=200, n_seg=341
# fs=50Hz: T_res=34218, STEP=200, n_seg=170
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-026\eeg/
# [PASS 1] Subject: sub-026
#   reading header: ADFTD-RS/derivatives\sub-026\eeg/sub-026_task-eyesclosed_eeg.set
# fs=200Hz: T_res=179728, STEP=200, n_seg=897
# fs=100Hz: T_res=89864, STEP=200, n_seg=448
# fs=50Hz: T_res=44932, STEP=200, n_seg=223
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-027\eeg/
# [PASS 1] Subject: sub-027
#   reading header: ADFTD-RS/derivatives\sub-027\eeg/sub-027_task-eyesclosed_eeg.set
# fs=200Hz: T_res=165240, STEP=200, n_seg=825
# fs=100Hz: T_res=82620, STEP=200, n_seg=412
# fs=50Hz: T_res=41310, STEP=200, n_seg=205
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-028\eeg/
# [PASS 1] Subject: sub-028
#   reading header: ADFTD-RS/derivatives\sub-028\eeg/sub-028_task-eyesclosed_eeg.set
# fs=200Hz: T_res=163628, STEP=200, n_seg=817
# fs=100Hz: T_res=81814, STEP=200, n_seg=408
# fs=50Hz: T_res=40907, STEP=200, n_seg=203
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-029\eeg/
# [PASS 1] Subject: sub-029
#   reading header: ADFTD-RS/derivatives\sub-029\eeg/sub-029_task-eyesclosed_eeg.set
# fs=200Hz: T_res=147336, STEP=200, n_seg=735
# fs=100Hz: T_res=73668, STEP=200, n_seg=367
# fs=50Hz: T_res=36834, STEP=200, n_seg=183
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-030\eeg/
# [PASS 1] Subject: sub-030
#   reading header: ADFTD-RS/derivatives\sub-030\eeg/sub-030_task-eyesclosed_eeg.set
# fs=200Hz: T_res=110816, STEP=200, n_seg=553
# fs=100Hz: T_res=55408, STEP=200, n_seg=276
# fs=50Hz: T_res=27704, STEP=200, n_seg=137
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-031\eeg/
# [PASS 1] Subject: sub-031
#   reading header: ADFTD-RS/derivatives\sub-031\eeg/sub-031_task-eyesclosed_eeg.set
# fs=200Hz: T_res=230152, STEP=200, n_seg=1149
# fs=100Hz: T_res=115076, STEP=200, n_seg=574
# fs=50Hz: T_res=57538, STEP=200, n_seg=286
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-032\eeg/
# [PASS 1] Subject: sub-032
#   reading header: ADFTD-RS/derivatives\sub-032\eeg/sub-032_task-eyesclosed_eeg.set
# fs=200Hz: T_res=159556, STEP=200, n_seg=796
# fs=100Hz: T_res=79778, STEP=200, n_seg=397
# fs=50Hz: T_res=39889, STEP=200, n_seg=198
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-033\eeg/
# [PASS 1] Subject: sub-033
#   reading header: ADFTD-RS/derivatives\sub-033\eeg/sub-033_task-eyesclosed_eeg.set
# fs=200Hz: T_res=141084, STEP=200, n_seg=704
# fs=100Hz: T_res=70542, STEP=200, n_seg=351
# fs=50Hz: T_res=35271, STEP=200, n_seg=175
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-034\eeg/
# [PASS 1] Subject: sub-034
#   reading header: ADFTD-RS/derivatives\sub-034\eeg/sub-034_task-eyesclosed_eeg.set
# fs=200Hz: T_res=193980, STEP=200, n_seg=968
# fs=100Hz: T_res=96990, STEP=200, n_seg=483
# fs=50Hz: T_res=48495, STEP=200, n_seg=241
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-035\eeg/
# [PASS 1] Subject: sub-035
#   reading header: ADFTD-RS/derivatives\sub-035\eeg/sub-035_task-eyesclosed_eeg.set
# fs=200Hz: T_res=148208, STEP=200, n_seg=740
# fs=100Hz: T_res=74104, STEP=200, n_seg=369
# fs=50Hz: T_res=37052, STEP=200, n_seg=184
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-036\eeg/
# [PASS 1] Subject: sub-036
#   reading header: ADFTD-RS/derivatives\sub-036\eeg/sub-036_task-eyesclosed_eeg.set
# fs=200Hz: T_res=168272, STEP=200, n_seg=840
# fs=100Hz: T_res=84136, STEP=200, n_seg=419
# fs=50Hz: T_res=42068, STEP=200, n_seg=209
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-037\eeg/
# [PASS 1] Subject: sub-037
#   reading header: ADFTD-RS/derivatives\sub-037\eeg/sub-037_task-eyesclosed_eeg.set
# fs=200Hz: T_res=155420, STEP=200, n_seg=776
# fs=100Hz: T_res=77710, STEP=200, n_seg=387
# fs=50Hz: T_res=38855, STEP=200, n_seg=193
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-038\eeg/
# [PASS 1] Subject: sub-038
#   reading header: ADFTD-RS/derivatives\sub-038\eeg/sub-038_task-eyesclosed_eeg.set
# fs=200Hz: T_res=178280, STEP=200, n_seg=890
# fs=100Hz: T_res=89140, STEP=200, n_seg=444
# fs=50Hz: T_res=44570, STEP=200, n_seg=221
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-039\eeg/
# [PASS 1] Subject: sub-039
#   reading header: ADFTD-RS/derivatives\sub-039\eeg/sub-039_task-eyesclosed_eeg.set
# fs=200Hz: T_res=170016, STEP=200, n_seg=849
# fs=100Hz: T_res=85008, STEP=200, n_seg=424
# fs=50Hz: T_res=42504, STEP=200, n_seg=211
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-040\eeg/
# [PASS 1] Subject: sub-040
#   reading header: ADFTD-RS/derivatives\sub-040\eeg/sub-040_task-eyesclosed_eeg.set
# fs=200Hz: T_res=193148, STEP=200, n_seg=964
# fs=100Hz: T_res=96574, STEP=200, n_seg=481
# fs=50Hz: T_res=48287, STEP=200, n_seg=240
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-041\eeg/
# [PASS 1] Subject: sub-041
#   reading header: ADFTD-RS/derivatives\sub-041\eeg/sub-041_task-eyesclosed_eeg.set
# fs=200Hz: T_res=177220, STEP=200, n_seg=885
# fs=100Hz: T_res=88610, STEP=200, n_seg=442
# fs=50Hz: T_res=44305, STEP=200, n_seg=220
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-042\eeg/
# [PASS 1] Subject: sub-042
#   reading header: ADFTD-RS/derivatives\sub-042\eeg/sub-042_task-eyesclosed_eeg.set
# fs=200Hz: T_res=192604, STEP=200, n_seg=962
# fs=100Hz: T_res=96302, STEP=200, n_seg=480
# fs=50Hz: T_res=48151, STEP=200, n_seg=239
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-043\eeg/
# [PASS 1] Subject: sub-043
#   reading header: ADFTD-RS/derivatives\sub-043\eeg/sub-043_task-eyesclosed_eeg.set
# fs=200Hz: T_res=165820, STEP=200, n_seg=828
# fs=100Hz: T_res=82910, STEP=200, n_seg=413
# fs=50Hz: T_res=41455, STEP=200, n_seg=206
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-044\eeg/
# [PASS 1] Subject: sub-044
#   reading header: ADFTD-RS/derivatives\sub-044\eeg/sub-044_task-eyesclosed_eeg.set
# fs=200Hz: T_res=176320, STEP=200, n_seg=880
# fs=100Hz: T_res=88160, STEP=200, n_seg=439
# fs=50Hz: T_res=44080, STEP=200, n_seg=219
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-045\eeg/
# [PASS 1] Subject: sub-045
#   reading header: ADFTD-RS/derivatives\sub-045\eeg/sub-045_task-eyesclosed_eeg.set
# fs=200Hz: T_res=170328, STEP=200, n_seg=850
# fs=100Hz: T_res=85164, STEP=200, n_seg=424
# fs=50Hz: T_res=42582, STEP=200, n_seg=211
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-046\eeg/
# [PASS 1] Subject: sub-046
#   reading header: ADFTD-RS/derivatives\sub-046\eeg/sub-046_task-eyesclosed_eeg.set
# fs=200Hz: T_res=150608, STEP=200, n_seg=752
# fs=100Hz: T_res=75304, STEP=200, n_seg=375
# fs=50Hz: T_res=37652, STEP=200, n_seg=187
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-047\eeg/
# [PASS 1] Subject: sub-047
#   reading header: ADFTD-RS/derivatives\sub-047\eeg/sub-047_task-eyesclosed_eeg.set
# fs=200Hz: T_res=161400, STEP=200, n_seg=806
# fs=100Hz: T_res=80700, STEP=200, n_seg=402
# fs=50Hz: T_res=40350, STEP=200, n_seg=200
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-048\eeg/
# [PASS 1] Subject: sub-048
#   reading header: ADFTD-RS/derivatives\sub-048\eeg/sub-048_task-eyesclosed_eeg.set
# fs=200Hz: T_res=197976, STEP=200, n_seg=988
# fs=100Hz: T_res=98988, STEP=200, n_seg=493
# fs=50Hz: T_res=49494, STEP=200, n_seg=246
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-049\eeg/
# [PASS 1] Subject: sub-049
#   reading header: ADFTD-RS/derivatives\sub-049\eeg/sub-049_task-eyesclosed_eeg.set
# fs=200Hz: T_res=156040, STEP=200, n_seg=779
# fs=100Hz: T_res=78020, STEP=200, n_seg=389
# fs=50Hz: T_res=39010, STEP=200, n_seg=194
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-050\eeg/
# [PASS 1] Subject: sub-050
#   reading header: ADFTD-RS/derivatives\sub-050\eeg/sub-050_task-eyesclosed_eeg.set
# fs=200Hz: T_res=163528, STEP=200, n_seg=816
# fs=100Hz: T_res=81764, STEP=200, n_seg=407
# fs=50Hz: T_res=40882, STEP=200, n_seg=203
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-051\eeg/
# [PASS 1] Subject: sub-051
#   reading header: ADFTD-RS/derivatives\sub-051\eeg/sub-051_task-eyesclosed_eeg.set
# fs=200Hz: T_res=150668, STEP=200, n_seg=752
# fs=100Hz: T_res=75334, STEP=200, n_seg=375
# fs=50Hz: T_res=37667, STEP=200, n_seg=187
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-052\eeg/
# [PASS 1] Subject: sub-052
#   reading header: ADFTD-RS/derivatives\sub-052\eeg/sub-052_task-eyesclosed_eeg.set
# fs=200Hz: T_res=152020, STEP=200, n_seg=759
# fs=100Hz: T_res=76010, STEP=200, n_seg=379
# fs=50Hz: T_res=38005, STEP=200, n_seg=189
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-053\eeg/
# [PASS 1] Subject: sub-053
#   reading header: ADFTD-RS/derivatives\sub-053\eeg/sub-053_task-eyesclosed_eeg.set
# fs=200Hz: T_res=156104, STEP=200, n_seg=779
# fs=100Hz: T_res=78052, STEP=200, n_seg=389
# fs=50Hz: T_res=39026, STEP=200, n_seg=194
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-054\eeg/
# [PASS 1] Subject: sub-054
#   reading header: ADFTD-RS/derivatives\sub-054\eeg/sub-054_task-eyesclosed_eeg.set
# fs=200Hz: T_res=167524, STEP=200, n_seg=836
# fs=100Hz: T_res=83762, STEP=200, n_seg=417
# fs=50Hz: T_res=41881, STEP=200, n_seg=208
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-055\eeg/
# [PASS 1] Subject: sub-055
#   reading header: ADFTD-RS/derivatives\sub-055\eeg/sub-055_task-eyesclosed_eeg.set
# fs=200Hz: T_res=162920, STEP=200, n_seg=813
# fs=100Hz: T_res=81460, STEP=200, n_seg=406
# fs=50Hz: T_res=40730, STEP=200, n_seg=202
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-056\eeg/
# [PASS 1] Subject: sub-056
#   reading header: ADFTD-RS/derivatives\sub-056\eeg/sub-056_task-eyesclosed_eeg.set
# fs=200Hz: T_res=158264, STEP=200, n_seg=790
# fs=100Hz: T_res=79132, STEP=200, n_seg=394
# fs=50Hz: T_res=39566, STEP=200, n_seg=196
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-057\eeg/
# [PASS 1] Subject: sub-057
#   reading header: ADFTD-RS/derivatives\sub-057\eeg/sub-057_task-eyesclosed_eeg.set
# fs=200Hz: T_res=159300, STEP=200, n_seg=795
# fs=100Hz: T_res=79650, STEP=200, n_seg=397
# fs=50Hz: T_res=39825, STEP=200, n_seg=198
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-058\eeg/
# [PASS 1] Subject: sub-058
#   reading header: ADFTD-RS/derivatives\sub-058\eeg/sub-058_task-eyesclosed_eeg.set
# fs=200Hz: T_res=151356, STEP=200, n_seg=755
# fs=100Hz: T_res=75678, STEP=200, n_seg=377
# fs=50Hz: T_res=37839, STEP=200, n_seg=188
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-059\eeg/
# [PASS 1] Subject: sub-059
#   reading header: ADFTD-RS/derivatives\sub-059\eeg/sub-059_task-eyesclosed_eeg.set
# fs=200Hz: T_res=157424, STEP=200, n_seg=786
# fs=100Hz: T_res=78712, STEP=200, n_seg=392
# fs=50Hz: T_res=39356, STEP=200, n_seg=195
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-060\eeg/
# [PASS 1] Subject: sub-060
#   reading header: ADFTD-RS/derivatives\sub-060\eeg/sub-060_task-eyesclosed_eeg.set
# fs=200Hz: T_res=149696, STEP=200, n_seg=747
# fs=100Hz: T_res=74848, STEP=200, n_seg=373
# fs=50Hz: T_res=37424, STEP=200, n_seg=186
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-061\eeg/
# [PASS 1] Subject: sub-061
#   reading header: ADFTD-RS/derivatives\sub-061\eeg/sub-061_task-eyesclosed_eeg.set
# fs=200Hz: T_res=160656, STEP=200, n_seg=802
# fs=100Hz: T_res=80328, STEP=200, n_seg=400
# fs=50Hz: T_res=40164, STEP=200, n_seg=199
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-062\eeg/
# [PASS 1] Subject: sub-062
#   reading header: ADFTD-RS/derivatives\sub-062\eeg/sub-062_task-eyesclosed_eeg.set
# fs=200Hz: T_res=179740, STEP=200, n_seg=897
# fs=100Hz: T_res=89870, STEP=200, n_seg=448
# fs=50Hz: T_res=44935, STEP=200, n_seg=223
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-063\eeg/
# [PASS 1] Subject: sub-063
#   reading header: ADFTD-RS/derivatives\sub-063\eeg/sub-063_task-eyesclosed_eeg.set
# fs=200Hz: T_res=160988, STEP=200, n_seg=803
# fs=100Hz: T_res=80494, STEP=200, n_seg=401
# fs=50Hz: T_res=40247, STEP=200, n_seg=200
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-064\eeg/
# [PASS 1] Subject: sub-064
#   reading header: ADFTD-RS/derivatives\sub-064\eeg/sub-064_task-eyesclosed_eeg.set
# fs=200Hz: T_res=169620, STEP=200, n_seg=847
# fs=100Hz: T_res=84810, STEP=200, n_seg=423
# fs=50Hz: T_res=42405, STEP=200, n_seg=211
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-065\eeg/
# [PASS 1] Subject: sub-065
#   reading header: ADFTD-RS/derivatives\sub-065\eeg/sub-065_task-eyesclosed_eeg.set
# fs=200Hz: T_res=176820, STEP=200, n_seg=883
# fs=100Hz: T_res=88410, STEP=200, n_seg=441
# fs=50Hz: T_res=44205, STEP=200, n_seg=220
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-066\eeg/
# [PASS 1] Subject: sub-066
#   reading header: ADFTD-RS/derivatives\sub-066\eeg/sub-066_task-eyesclosed_eeg.set
# fs=200Hz: T_res=109952, STEP=200, n_seg=548
# fs=100Hz: T_res=54976, STEP=200, n_seg=273
# fs=50Hz: T_res=27488, STEP=200, n_seg=136
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-067\eeg/
# [PASS 1] Subject: sub-067
#   reading header: ADFTD-RS/derivatives\sub-067\eeg/sub-067_task-eyesclosed_eeg.set
# fs=200Hz: T_res=128620, STEP=200, n_seg=642
# fs=100Hz: T_res=64310, STEP=200, n_seg=320
# fs=50Hz: T_res=32155, STEP=200, n_seg=159
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-068\eeg/
# [PASS 1] Subject: sub-068
#   reading header: ADFTD-RS/derivatives\sub-068\eeg/sub-068_task-eyesclosed_eeg.set
# fs=200Hz: T_res=114620, STEP=200, n_seg=572
# fs=100Hz: T_res=57310, STEP=200, n_seg=285
# fs=50Hz: T_res=28655, STEP=200, n_seg=142
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-069\eeg/
# [PASS 1] Subject: sub-069
#   reading header: ADFTD-RS/derivatives\sub-069\eeg/sub-069_task-eyesclosed_eeg.set
# fs=200Hz: T_res=127220, STEP=200, n_seg=635
# fs=100Hz: T_res=63610, STEP=200, n_seg=317
# fs=50Hz: T_res=31805, STEP=200, n_seg=158
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-070\eeg/
# [PASS 1] Subject: sub-070
#   reading header: ADFTD-RS/derivatives\sub-070\eeg/sub-070_task-eyesclosed_eeg.set
# fs=200Hz: T_res=95820, STEP=200, n_seg=478
# fs=100Hz: T_res=47910, STEP=200, n_seg=238
# fs=50Hz: T_res=23955, STEP=200, n_seg=118
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-071\eeg/
# [PASS 1] Subject: sub-071
#   reading header: ADFTD-RS/derivatives\sub-071\eeg/sub-071_task-eyesclosed_eeg.set
# fs=200Hz: T_res=123780, STEP=200, n_seg=617
# fs=100Hz: T_res=61890, STEP=200, n_seg=308
# fs=50Hz: T_res=30945, STEP=200, n_seg=153
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-072\eeg/
# [PASS 1] Subject: sub-072
#   reading header: ADFTD-RS/derivatives\sub-072\eeg/sub-072_task-eyesclosed_eeg.set
# fs=200Hz: T_res=131484, STEP=200, n_seg=656
# fs=100Hz: T_res=65742, STEP=200, n_seg=327
# fs=50Hz: T_res=32871, STEP=200, n_seg=163
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-073\eeg/
# [PASS 1] Subject: sub-073
#   reading header: ADFTD-RS/derivatives\sub-073\eeg/sub-073_task-eyesclosed_eeg.set
# fs=200Hz: T_res=170916, STEP=200, n_seg=853
# fs=100Hz: T_res=85458, STEP=200, n_seg=426
# fs=50Hz: T_res=42729, STEP=200, n_seg=212
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-074\eeg/
# [PASS 1] Subject: sub-074
#   reading header: ADFTD-RS/derivatives\sub-074\eeg/sub-074_task-eyesclosed_eeg.set
# fs=200Hz: T_res=202900, STEP=200, n_seg=1013
# fs=100Hz: T_res=101450, STEP=200, n_seg=506
# fs=50Hz: T_res=50725, STEP=200, n_seg=252
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-075\eeg/
# [PASS 1] Subject: sub-075
#   reading header: ADFTD-RS/derivatives\sub-075\eeg/sub-075_task-eyesclosed_eeg.set
# fs=200Hz: T_res=149636, STEP=200, n_seg=747
# fs=100Hz: T_res=74818, STEP=200, n_seg=373
# fs=50Hz: T_res=37409, STEP=200, n_seg=186
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-076\eeg/
# [PASS 1] Subject: sub-076
#   reading header: ADFTD-RS/derivatives\sub-076\eeg/sub-076_task-eyesclosed_eeg.set
# fs=200Hz: T_res=163760, STEP=200, n_seg=817
# fs=100Hz: T_res=81880, STEP=200, n_seg=408
# fs=50Hz: T_res=40940, STEP=200, n_seg=203
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-077\eeg/
# [PASS 1] Subject: sub-077
#   reading header: ADFTD-RS/derivatives\sub-077\eeg/sub-077_task-eyesclosed_eeg.set
# fs=200Hz: T_res=139828, STEP=200, n_seg=698
# fs=100Hz: T_res=69914, STEP=200, n_seg=348
# fs=50Hz: T_res=34957, STEP=200, n_seg=173
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-078\eeg/
# [PASS 1] Subject: sub-078
#   reading header: ADFTD-RS/derivatives\sub-078\eeg/sub-078_task-eyesclosed_eeg.set
# fs=200Hz: T_res=174180, STEP=200, n_seg=869
# fs=100Hz: T_res=87090, STEP=200, n_seg=434
# fs=50Hz: T_res=43545, STEP=200, n_seg=216
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-079\eeg/
# [PASS 1] Subject: sub-079
#   reading header: ADFTD-RS/derivatives\sub-079\eeg/sub-079_task-eyesclosed_eeg.set
# fs=200Hz: T_res=163336, STEP=200, n_seg=815
# fs=100Hz: T_res=81668, STEP=200, n_seg=407
# fs=50Hz: T_res=40834, STEP=200, n_seg=203
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-080\eeg/
# [PASS 1] Subject: sub-080
#   reading header: ADFTD-RS/derivatives\sub-080\eeg/sub-080_task-eyesclosed_eeg.set
# fs=200Hz: T_res=183028, STEP=200, n_seg=914
# fs=100Hz: T_res=91514, STEP=200, n_seg=456
# fs=50Hz: T_res=45757, STEP=200, n_seg=227
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-081\eeg/
# [PASS 1] Subject: sub-081
#   reading header: ADFTD-RS/derivatives\sub-081\eeg/sub-081_task-eyesclosed_eeg.set
# fs=200Hz: T_res=164896, STEP=200, n_seg=823
# fs=100Hz: T_res=82448, STEP=200, n_seg=411
# fs=50Hz: T_res=41224, STEP=200, n_seg=205
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-082\eeg/
# [PASS 1] Subject: sub-082
#   reading header: ADFTD-RS/derivatives\sub-082\eeg/sub-082_task-eyesclosed_eeg.set
# fs=200Hz: T_res=155520, STEP=200, n_seg=776
# fs=100Hz: T_res=77760, STEP=200, n_seg=387
# fs=50Hz: T_res=38880, STEP=200, n_seg=193
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-083\eeg/
# [PASS 1] Subject: sub-083
#   reading header: ADFTD-RS/derivatives\sub-083\eeg/sub-083_task-eyesclosed_eeg.set
# fs=200Hz: T_res=182640, STEP=200, n_seg=912
# fs=100Hz: T_res=91320, STEP=200, n_seg=455
# fs=50Hz: T_res=45660, STEP=200, n_seg=227
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-084\eeg/
# [PASS 1] Subject: sub-084
#   reading header: ADFTD-RS/derivatives\sub-084\eeg/sub-084_task-eyesclosed_eeg.set
# fs=200Hz: T_res=130420, STEP=200, n_seg=651
# fs=100Hz: T_res=65210, STEP=200, n_seg=325
# fs=50Hz: T_res=32605, STEP=200, n_seg=162
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-085\eeg/
# [PASS 1] Subject: sub-085
#   reading header: ADFTD-RS/derivatives\sub-085\eeg/sub-085_task-eyesclosed_eeg.set
# fs=200Hz: T_res=112012, STEP=200, n_seg=559
# fs=100Hz: T_res=56006, STEP=200, n_seg=279
# fs=50Hz: T_res=28003, STEP=200, n_seg=139
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-086\eeg/
# [PASS 1] Subject: sub-086
#   reading header: ADFTD-RS/derivatives\sub-086\eeg/sub-086_task-eyesclosed_eeg.set
# fs=200Hz: T_res=115760, STEP=200, n_seg=577
# fs=100Hz: T_res=57880, STEP=200, n_seg=288
# fs=50Hz: T_res=28940, STEP=200, n_seg=143
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-087\eeg/
# [PASS 1] Subject: sub-087
#   reading header: ADFTD-RS/derivatives\sub-087\eeg/sub-087_task-eyesclosed_eeg.set
# fs=200Hz: T_res=120552, STEP=200, n_seg=601
# fs=100Hz: T_res=60276, STEP=200, n_seg=300
# fs=50Hz: T_res=30138, STEP=200, n_seg=149
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-088\eeg/
# [PASS 1] Subject: sub-088
#   reading header: ADFTD-RS/derivatives\sub-088\eeg/sub-088_task-eyesclosed_eeg.set
# fs=200Hz: T_res=156940, STEP=200, n_seg=783
# fs=100Hz: T_res=78470, STEP=200, n_seg=391
# fs=50Hz: T_res=39235, STEP=200, n_seg=195
# -------------------------------------
#
#
# ===================================
# Total segments N_total = 121825
# Channels = 19
# ===================================

# %%
output_root = os.path.join('Processed', sub_folder_path, 'ADFTD-RS')
os.makedirs(output_root, exist_ok=True)

X_path = os.path.join(output_root, 'X.dat')
y_path = os.path.join(output_root, 'y.dat')
meta_path = os.path.join(output_root, 'meta.json')

print("X path:", X_path)
print("y path:", y_path)

# create memmap storage
X_mm = np.memmap(X_path, dtype='float32', mode='w+', shape=(N_total, SEG_LEN, n_channels))
y_mm = np.memmap(y_path, dtype='float32', mode='w+', shape=(N_total, 3))
# Out:
# X path: Processed\L400\ADFTD-RS\X.dat
# y path: Processed\L400\ADFTD-RS\y.dat

# %% [markdown]
# ## PASS 2: Process and store segments into memmap

# %%
cur = 0  # current index in memmap
total_seconds_all = 0  # used for total hours calculation
for sub in sorted(os.listdir(derivatives_root)):
    if 'sub-' in sub:
        label, pid = sub_info[sub]
        sub_path = os.path.join(derivatives_root, sub, 'eeg')
        print(sub_path)
        if sub not in sub_info:
            continue
    
        total_seg_sub = sum(subject_segment_counts[sub][fs] for fs in SAMPLE_RATE_LIST)
        if total_seg_sub == 0:
            continue
        print(f"[PASS 2] Subject: {sub}, expected total segments={total_seg_sub}")
    
        for file in os.listdir(sub_path):
            if '.set' in file:
                file_path = os.path.join(sub_path, file)
                print("  load:", file_path)
        
                # load full data
                raw = mne.io.read_raw_eeglab(file_path, preload=True)
                original_fs = raw.info['sfreq']
                data_raw = raw.get_data().T.astype('float32')  # (C, T) -> (T, C)
                total_seconds_all += data_raw.shape[0] / original_fs
                print("raw shape:", data_raw.shape)
        
                for fs in SAMPLE_RATE_LIST:
                    # resample to target fs
                    data = resample_time_series(data_raw, original_fs, fs)
                    T_res, _ = data.shape
                    print(f"fs={fs}Hz: resampled shape={data.shape}")
        
                    # overlapped sliding window with fixed STEP (in timestamps)
                    starts = np.arange(0, T_res - SEG_LEN + 1, STEP, dtype=int)
                    print(f"fs={fs}Hz: segments={len(starts)}")
        
                    for s in starts:
                        if cur >= N_total:
                            raise RuntimeError("Exceeded predicted N_total.")
        
                        X_mm[cur] = data[s:s + SEG_LEN]   # (SEG_LEN, C)
                        y_mm[cur, 0] = float(label)       # label
                        y_mm[cur, 1] = float(pid)         # subject ID
                        y_mm[cur, 2] = float(fs)          # sample rate (scale)
                        cur += 1
    print("-------------------------------------\n")

total_hours_all = total_seconds_all / 3600.0
print("DONE: cur =", cur, " expected N_total =", N_total)
print(f"Total hours across all subjects: {total_hours_all:.2f} hours")

# flush
del X_mm
del y_mm

# save meta
meta = {
    "N": int(N_total),
    "T": SEG_LEN,
    "C": int(n_channels),
    "SAMPLE_RATE_LIST": SAMPLE_RATE_LIST,
    "OVERLAP": int(OVERLAP),   # in samples
    "STEP": int(STEP),
    "X_path": X_path,
    "y_path": y_path,
}
with open(meta_path, "w") as f:
    json.dump(meta, f, indent=2)

print("Saved meta:", meta_path)
# Out:
# ADFTD-RS/derivatives\sub-001\eeg
# [PASS 2] Subject: sub-001, expected total segments=1044
#   load: ADFTD-RS/derivatives\sub-001\eeg\sub-001_task-eyesclosed_eeg.set
# raw shape: (299900, 19)
# fs=200Hz: resampled shape=(119960, 19)
# fs=200Hz: segments=598
# fs=100Hz: resampled shape=(59980, 19)
# fs=100Hz: segments=298
# fs=50Hz: resampled shape=(29990, 19)
# fs=50Hz: segments=148
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-002\eeg
# [PASS 2] Subject: sub-002, expected total segments=1384
#   load: ADFTD-RS/derivatives\sub-002\eeg\sub-002_task-eyesclosed_eeg.set
# raw shape: (396550, 19)
# fs=200Hz: resampled shape=(158620, 19)
# fs=200Hz: segments=792
# fs=100Hz: resampled shape=(79310, 19)
# fs=100Hz: segments=395
# fs=50Hz: resampled shape=(39655, 19)
# fs=50Hz: segments=197
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-003\eeg
# [PASS 2] Subject: sub-003, expected total segments=532
#   load: ADFTD-RS/derivatives\sub-003\eeg\sub-003_task-eyesclosed_eeg.set
# raw shape: (153050, 19)
# fs=200Hz: resampled shape=(61220, 19)
# fs=200Hz: segments=305
# fs=100Hz: resampled shape=(30610, 19)
# fs=100Hz: segments=152
# fs=50Hz: resampled shape=(15305, 19)
# fs=50Hz: segments=75
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-004\eeg
# [PASS 2] Subject: sub-004, expected total segments=1232
#   load: ADFTD-RS/derivatives\sub-004\eeg\sub-004_task-eyesclosed_eeg.set
# raw shape: (353050, 19)
# fs=200Hz: resampled shape=(141220, 19)
# fs=200Hz: segments=705
# fs=100Hz: resampled shape=(70610, 19)
# fs=100Hz: segments=352
# fs=50Hz: resampled shape=(35305, 19)
# fs=50Hz: segments=175
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-005\eeg
# [PASS 2] Subject: sub-005, expected total segments=1404
#   load: ADFTD-RS/derivatives\sub-005\eeg\sub-005_task-eyesclosed_eeg.set
# raw shape: (402050, 19)
# fs=200Hz: resampled shape=(160820, 19)
# fs=200Hz: segments=803
# fs=100Hz: resampled shape=(80410, 19)
# fs=100Hz: segments=401
# fs=50Hz: resampled shape=(40205, 19)
# fs=50Hz: segments=200
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-006\eeg
# [PASS 2] Subject: sub-006, expected total segments=1103
#   load: ADFTD-RS/derivatives\sub-006\eeg\sub-006_task-eyesclosed_eeg.set
# raw shape: (316200, 19)
# fs=200Hz: resampled shape=(126480, 19)
# fs=200Hz: segments=631
# fs=100Hz: resampled shape=(63240, 19)
# fs=100Hz: segments=315
# fs=50Hz: resampled shape=(31620, 19)
# fs=50Hz: segments=157
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-007\eeg
# [PASS 2] Subject: sub-007, expected total segments=1337
#   load: ADFTD-RS/derivatives\sub-007\eeg\sub-007_task-eyesclosed_eeg.set
# raw shape: (383210, 19)
# fs=200Hz: resampled shape=(153284, 19)
# fs=200Hz: segments=765
# fs=100Hz: resampled shape=(76642, 19)
# fs=100Hz: segments=382
# fs=50Hz: resampled shape=(38321, 19)
# fs=50Hz: segments=190
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-008\eeg
# [PASS 2] Subject: sub-008, expected total segments=1384
#   load: ADFTD-RS/derivatives\sub-008\eeg\sub-008_task-eyesclosed_eeg.set
# raw shape: (396700, 19)
# fs=200Hz: resampled shape=(158680, 19)
# fs=200Hz: segments=792
# fs=100Hz: resampled shape=(79340, 19)
# fs=100Hz: segments=395
# fs=50Hz: resampled shape=(39670, 19)
# fs=50Hz: segments=197
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-009\eeg
# [PASS 2] Subject: sub-009, expected total segments=1068
#   load: ADFTD-RS/derivatives\sub-009\eeg\sub-009_task-eyesclosed_eeg.set
# raw shape: (306300, 19)
# fs=200Hz: resampled shape=(122520, 19)
# fs=200Hz: segments=611
# fs=100Hz: resampled shape=(61260, 19)
# fs=100Hz: segments=305
# fs=50Hz: resampled shape=(30630, 19)
# fs=50Hz: segments=152
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-010\eeg
# [PASS 2] Subject: sub-010, expected total segments=2238
#   load: ADFTD-RS/derivatives\sub-010\eeg\sub-010_task-eyesclosed_eeg.set
# raw shape: (640860, 19)
# fs=200Hz: resampled shape=(256344, 19)
# fs=200Hz: segments=1280
# fs=100Hz: resampled shape=(128172, 19)
# fs=100Hz: segments=639
# fs=50Hz: resampled shape=(64086, 19)
# fs=50Hz: segments=319
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-011\eeg
# [PASS 2] Subject: sub-011, expected total segments=1342
#   load: ADFTD-RS/derivatives\sub-011\eeg\sub-011_task-eyesclosed_eeg.set
# raw shape: (384960, 19)
# fs=200Hz: resampled shape=(153984, 19)
# fs=200Hz: segments=768
# fs=100Hz: resampled shape=(76992, 19)
# fs=100Hz: segments=383
# fs=50Hz: resampled shape=(38496, 19)
# fs=50Hz: segments=191
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-012\eeg
# [PASS 2] Subject: sub-012, expected total segments=1541
#   load: ADFTD-RS/derivatives\sub-012\eeg\sub-012_task-eyesclosed_eeg.set
# raw shape: (441760, 19)
# fs=200Hz: resampled shape=(176704, 19)
# fs=200Hz: segments=882
# fs=100Hz: resampled shape=(88352, 19)
# fs=100Hz: segments=440
# fs=50Hz: resampled shape=(44176, 19)
# fs=50Hz: segments=219
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-013\eeg
# [PASS 2] Subject: sub-013, expected total segments=1463
#   load: ADFTD-RS/derivatives\sub-013\eeg\sub-013_task-eyesclosed_eeg.set
# raw shape: (419050, 19)
# fs=200Hz: resampled shape=(167620, 19)
# fs=200Hz: segments=837
# fs=100Hz: resampled shape=(83810, 19)
# fs=100Hz: segments=418
# fs=50Hz: resampled shape=(41905, 19)
# fs=50Hz: segments=208
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-014\eeg
# [PASS 2] Subject: sub-014, expected total segments=1631
#   load: ADFTD-RS/derivatives\sub-014\eeg\sub-014_task-eyesclosed_eeg.set
# raw shape: (467220, 19)
# fs=200Hz: resampled shape=(186888, 19)
# fs=200Hz: segments=933
# fs=100Hz: resampled shape=(93444, 19)
# fs=100Hz: segments=466
# fs=50Hz: resampled shape=(46722, 19)
# fs=50Hz: segments=232
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-015\eeg
# [PASS 2] Subject: sub-015, expected total segments=1573
#   load: ADFTD-RS/derivatives\sub-015\eeg\sub-015_task-eyesclosed_eeg.set
# raw shape: (450690, 19)
# fs=200Hz: resampled shape=(180276, 19)
# fs=200Hz: segments=900
# fs=100Hz: resampled shape=(90138, 19)
# fs=100Hz: segments=449
# fs=50Hz: resampled shape=(45069, 19)
# fs=50Hz: segments=224
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-016\eeg
# [PASS 2] Subject: sub-016, expected total segments=1698
#   load: ADFTD-RS/derivatives\sub-016\eeg\sub-016_task-eyesclosed_eeg.set
# raw shape: (486180, 19)
# fs=200Hz: resampled shape=(194472, 19)
# fs=200Hz: segments=971
# fs=100Hz: resampled shape=(97236, 19)
# fs=100Hz: segments=485
# fs=50Hz: resampled shape=(48618, 19)
# fs=50Hz: segments=242
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-017\eeg
# [PASS 2] Subject: sub-017, expected total segments=1471
#   load: ADFTD-RS/derivatives\sub-017\eeg\sub-017_task-eyesclosed_eeg.set
# raw shape: (421700, 19)
# fs=200Hz: resampled shape=(168680, 19)
# fs=200Hz: segments=842
# fs=100Hz: resampled shape=(84340, 19)
# fs=100Hz: segments=420
# fs=50Hz: resampled shape=(42170, 19)
# fs=50Hz: segments=209
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-018\eeg
# [PASS 2] Subject: sub-018, expected total segments=1475
#   load: ADFTD-RS/derivatives\sub-018\eeg\sub-018_task-eyesclosed_eeg.set
# raw shape: (422550, 19)
# fs=200Hz: resampled shape=(169020, 19)
# fs=200Hz: segments=844
# fs=100Hz: resampled shape=(84510, 19)
# fs=100Hz: segments=421
# fs=50Hz: resampled shape=(42255, 19)
# fs=50Hz: segments=210
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-019\eeg
# [PASS 2] Subject: sub-019, expected total segments=1603
#   load: ADFTD-RS/derivatives\sub-019\eeg\sub-019_task-eyesclosed_eeg.set
# raw shape: (459310, 19)
# fs=200Hz: resampled shape=(183724, 19)
# fs=200Hz: segments=917
# fs=100Hz: resampled shape=(91862, 19)
# fs=100Hz: segments=458
# fs=50Hz: resampled shape=(45931, 19)
# fs=50Hz: segments=228
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-020\eeg
# [PASS 2] Subject: sub-020, expected total segments=1517
#   load: ADFTD-RS/derivatives\sub-020\eeg\sub-020_task-eyesclosed_eeg.set
# raw shape: (434650, 19)
# fs=200Hz: resampled shape=(173860, 19)
# fs=200Hz: segments=868
# fs=100Hz: resampled shape=(86930, 19)
# fs=100Hz: segments=433
# fs=50Hz: resampled shape=(43465, 19)
# fs=50Hz: segments=216
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-021\eeg
# [PASS 2] Subject: sub-021, expected total segments=1607
#   load: ADFTD-RS/derivatives\sub-021\eeg\sub-021_task-eyesclosed_eeg.set
# raw shape: (460140, 19)
# fs=200Hz: resampled shape=(184056, 19)
# fs=200Hz: segments=919
# fs=100Hz: resampled shape=(92028, 19)
# fs=100Hz: segments=459
# fs=50Hz: resampled shape=(46014, 19)
# fs=50Hz: segments=229
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-022\eeg
# [PASS 2] Subject: sub-022, expected total segments=1433
#   load: ADFTD-RS/derivatives\sub-022\eeg\sub-022_task-eyesclosed_eeg.set
# raw shape: (410960, 19)
# fs=200Hz: resampled shape=(164384, 19)
# fs=200Hz: segments=820
# fs=100Hz: resampled shape=(82192, 19)
# fs=100Hz: segments=409
# fs=50Hz: resampled shape=(41096, 19)
# fs=50Hz: segments=204
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-023\eeg
# [PASS 2] Subject: sub-023, expected total segments=1456
#   load: ADFTD-RS/derivatives\sub-023\eeg\sub-023_task-eyesclosed_eeg.set
# raw shape: (417370, 19)
# fs=200Hz: resampled shape=(166948, 19)
# fs=200Hz: segments=833
# fs=100Hz: resampled shape=(83474, 19)
# fs=100Hz: segments=416
# fs=50Hz: resampled shape=(41737, 19)
# fs=50Hz: segments=207
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-024\eeg
# [PASS 2] Subject: sub-024, expected total segments=1324
#   load: ADFTD-RS/derivatives\sub-024\eeg\sub-024_task-eyesclosed_eeg.set
# raw shape: (379900, 19)
# fs=200Hz: resampled shape=(151960, 19)
# fs=200Hz: segments=758
# fs=100Hz: resampled shape=(75980, 19)
# fs=100Hz: segments=378
# fs=50Hz: resampled shape=(37990, 19)
# fs=50Hz: segments=188
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-025\eeg
# [PASS 2] Subject: sub-025, expected total segments=1194
#   load: ADFTD-RS/derivatives\sub-025\eeg\sub-025_task-eyesclosed_eeg.set
# raw shape: (342180, 19)
# fs=200Hz: resampled shape=(136872, 19)
# fs=200Hz: segments=683
# fs=100Hz: resampled shape=(68436, 19)
# fs=100Hz: segments=341
# fs=50Hz: resampled shape=(34218, 19)
# fs=50Hz: segments=170
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-026\eeg
# [PASS 2] Subject: sub-026, expected total segments=1568
#   load: ADFTD-RS/derivatives\sub-026\eeg\sub-026_task-eyesclosed_eeg.set
# raw shape: (449320, 19)
# fs=200Hz: resampled shape=(179728, 19)
# fs=200Hz: segments=897
# fs=100Hz: resampled shape=(89864, 19)
# fs=100Hz: segments=448
# fs=50Hz: resampled shape=(44932, 19)
# fs=50Hz: segments=223
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-027\eeg
# [PASS 2] Subject: sub-027, expected total segments=1442
#   load: ADFTD-RS/derivatives\sub-027\eeg\sub-027_task-eyesclosed_eeg.set
# raw shape: (413100, 19)
# fs=200Hz: resampled shape=(165240, 19)
# fs=200Hz: segments=825
# fs=100Hz: resampled shape=(82620, 19)
# fs=100Hz: segments=412
# fs=50Hz: resampled shape=(41310, 19)
# fs=50Hz: segments=205
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-028\eeg
# [PASS 2] Subject: sub-028, expected total segments=1428
#   load: ADFTD-RS/derivatives\sub-028\eeg\sub-028_task-eyesclosed_eeg.set
# raw shape: (409070, 19)
# fs=200Hz: resampled shape=(163628, 19)
# fs=200Hz: segments=817
# fs=100Hz: resampled shape=(81814, 19)
# fs=100Hz: segments=408
# fs=50Hz: resampled shape=(40907, 19)
# fs=50Hz: segments=203
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-029\eeg
# [PASS 2] Subject: sub-029, expected total segments=1285
#   load: ADFTD-RS/derivatives\sub-029\eeg\sub-029_task-eyesclosed_eeg.set
# raw shape: (368340, 19)
# fs=200Hz: resampled shape=(147336, 19)
# fs=200Hz: segments=735
# fs=100Hz: resampled shape=(73668, 19)
# fs=100Hz: segments=367
# fs=50Hz: resampled shape=(36834, 19)
# fs=50Hz: segments=183
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-030\eeg
# [PASS 2] Subject: sub-030, expected total segments=966
#   load: ADFTD-RS/derivatives\sub-030\eeg\sub-030_task-eyesclosed_eeg.set
# raw shape: (277040, 19)
# fs=200Hz: resampled shape=(110816, 19)
# fs=200Hz: segments=553
# fs=100Hz: resampled shape=(55408, 19)
# fs=100Hz: segments=276
# fs=50Hz: resampled shape=(27704, 19)
# fs=50Hz: segments=137
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-031\eeg
# [PASS 2] Subject: sub-031, expected total segments=2009
#   load: ADFTD-RS/derivatives\sub-031\eeg\sub-031_task-eyesclosed_eeg.set
# raw shape: (575380, 19)
# fs=200Hz: resampled shape=(230152, 19)
# fs=200Hz: segments=1149
# fs=100Hz: resampled shape=(115076, 19)
# fs=100Hz: segments=574
# fs=50Hz: resampled shape=(57538, 19)
# fs=50Hz: segments=286
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-032\eeg
# [PASS 2] Subject: sub-032, expected total segments=1391
#   load: ADFTD-RS/derivatives\sub-032\eeg\sub-032_task-eyesclosed_eeg.set
# raw shape: (398890, 19)
# fs=200Hz: resampled shape=(159556, 19)
# fs=200Hz: segments=796
# fs=100Hz: resampled shape=(79778, 19)
# fs=100Hz: segments=397
# fs=50Hz: resampled shape=(39889, 19)
# fs=50Hz: segments=198
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-033\eeg
# [PASS 2] Subject: sub-033, expected total segments=1230
#   load: ADFTD-RS/derivatives\sub-033\eeg\sub-033_task-eyesclosed_eeg.set
# raw shape: (352710, 19)
# fs=200Hz: resampled shape=(141084, 19)
# fs=200Hz: segments=704
# fs=100Hz: resampled shape=(70542, 19)
# fs=100Hz: segments=351
# fs=50Hz: resampled shape=(35271, 19)
# fs=50Hz: segments=175
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-034\eeg
# [PASS 2] Subject: sub-034, expected total segments=1692
#   load: ADFTD-RS/derivatives\sub-034\eeg\sub-034_task-eyesclosed_eeg.set
# raw shape: (484950, 19)
# fs=200Hz: resampled shape=(193980, 19)
# fs=200Hz: segments=968
# fs=100Hz: resampled shape=(96990, 19)
# fs=100Hz: segments=483
# fs=50Hz: resampled shape=(48495, 19)
# fs=50Hz: segments=241
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-035\eeg
# [PASS 2] Subject: sub-035, expected total segments=1293
#   load: ADFTD-RS/derivatives\sub-035\eeg\sub-035_task-eyesclosed_eeg.set
# raw shape: (370520, 19)
# fs=200Hz: resampled shape=(148208, 19)
# fs=200Hz: segments=740
# fs=100Hz: resampled shape=(74104, 19)
# fs=100Hz: segments=369
# fs=50Hz: resampled shape=(37052, 19)
# fs=50Hz: segments=184
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-036\eeg
# [PASS 2] Subject: sub-036, expected total segments=1468
#   load: ADFTD-RS/derivatives\sub-036\eeg\sub-036_task-eyesclosed_eeg.set
# raw shape: (420680, 19)
# fs=200Hz: resampled shape=(168272, 19)
# fs=200Hz: segments=840
# fs=100Hz: resampled shape=(84136, 19)
# fs=100Hz: segments=419
# fs=50Hz: resampled shape=(42068, 19)
# fs=50Hz: segments=209
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-037\eeg
# [PASS 2] Subject: sub-037, expected total segments=1356
#   load: ADFTD-RS/derivatives\sub-037\eeg\sub-037_task-eyesclosed_eeg.set
# raw shape: (388550, 19)
# fs=200Hz: resampled shape=(155420, 19)
# fs=200Hz: segments=776
# fs=100Hz: resampled shape=(77710, 19)
# fs=100Hz: segments=387
# fs=50Hz: resampled shape=(38855, 19)
# fs=50Hz: segments=193
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-038\eeg
# [PASS 2] Subject: sub-038, expected total segments=1555
#   load: ADFTD-RS/derivatives\sub-038\eeg\sub-038_task-eyesclosed_eeg.set
# raw shape: (445700, 19)
# fs=200Hz: resampled shape=(178280, 19)
# fs=200Hz: segments=890
# fs=100Hz: resampled shape=(89140, 19)
# fs=100Hz: segments=444
# fs=50Hz: resampled shape=(44570, 19)
# fs=50Hz: segments=221
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-039\eeg
# [PASS 2] Subject: sub-039, expected total segments=1484
#   load: ADFTD-RS/derivatives\sub-039\eeg\sub-039_task-eyesclosed_eeg.set
# raw shape: (425040, 19)
# fs=200Hz: resampled shape=(170016, 19)
# fs=200Hz: segments=849
# fs=100Hz: resampled shape=(85008, 19)
# fs=100Hz: segments=424
# fs=50Hz: resampled shape=(42504, 19)
# fs=50Hz: segments=211
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-040\eeg
# [PASS 2] Subject: sub-040, expected total segments=1685
#   load: ADFTD-RS/derivatives\sub-040\eeg\sub-040_task-eyesclosed_eeg.set
# raw shape: (482870, 19)
# fs=200Hz: resampled shape=(193148, 19)
# fs=200Hz: segments=964
# fs=100Hz: resampled shape=(96574, 19)
# fs=100Hz: segments=481
# fs=50Hz: resampled shape=(48287, 19)
# fs=50Hz: segments=240
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-041\eeg
# [PASS 2] Subject: sub-041, expected total segments=1547
#   load: ADFTD-RS/derivatives\sub-041\eeg\sub-041_task-eyesclosed_eeg.set
# raw shape: (443050, 19)
# fs=200Hz: resampled shape=(177220, 19)
# fs=200Hz: segments=885
# fs=100Hz: resampled shape=(88610, 19)
# fs=100Hz: segments=442
# fs=50Hz: resampled shape=(44305, 19)
# fs=50Hz: segments=220
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-042\eeg
# [PASS 2] Subject: sub-042, expected total segments=1681
#   load: ADFTD-RS/derivatives\sub-042\eeg\sub-042_task-eyesclosed_eeg.set
# raw shape: (481510, 19)
# fs=200Hz: resampled shape=(192604, 19)
# fs=200Hz: segments=962
# fs=100Hz: resampled shape=(96302, 19)
# fs=100Hz: segments=480
# fs=50Hz: resampled shape=(48151, 19)
# fs=50Hz: segments=239
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-043\eeg
# [PASS 2] Subject: sub-043, expected total segments=1447
#   load: ADFTD-RS/derivatives\sub-043\eeg\sub-043_task-eyesclosed_eeg.set
# raw shape: (414550, 19)
# fs=200Hz: resampled shape=(165820, 19)
# fs=200Hz: segments=828
# fs=100Hz: resampled shape=(82910, 19)
# fs=100Hz: segments=413
# fs=50Hz: resampled shape=(41455, 19)
# fs=50Hz: segments=206
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-044\eeg
# [PASS 2] Subject: sub-044, expected total segments=1538
#   load: ADFTD-RS/derivatives\sub-044\eeg\sub-044_task-eyesclosed_eeg.set
# raw shape: (440800, 19)
# fs=200Hz: resampled shape=(176320, 19)
# fs=200Hz: segments=880
# fs=100Hz: resampled shape=(88160, 19)
# fs=100Hz: segments=439
# fs=50Hz: resampled shape=(44080, 19)
# fs=50Hz: segments=219
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-045\eeg
# [PASS 2] Subject: sub-045, expected total segments=1485
#   load: ADFTD-RS/derivatives\sub-045\eeg\sub-045_task-eyesclosed_eeg.set
# raw shape: (425820, 19)
# fs=200Hz: resampled shape=(170328, 19)
# fs=200Hz: segments=850
# fs=100Hz: resampled shape=(85164, 19)
# fs=100Hz: segments=424
# fs=50Hz: resampled shape=(42582, 19)
# fs=50Hz: segments=211
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-046\eeg
# [PASS 2] Subject: sub-046, expected total segments=1314
#   load: ADFTD-RS/derivatives\sub-046\eeg\sub-046_task-eyesclosed_eeg.set
# raw shape: (376520, 19)
# fs=200Hz: resampled shape=(150608, 19)
# fs=200Hz: segments=752
# fs=100Hz: resampled shape=(75304, 19)
# fs=100Hz: segments=375
# fs=50Hz: resampled shape=(37652, 19)
# fs=50Hz: segments=187
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-047\eeg
# [PASS 2] Subject: sub-047, expected total segments=1408
#   load: ADFTD-RS/derivatives\sub-047\eeg\sub-047_task-eyesclosed_eeg.set
# raw shape: (403500, 19)
# fs=200Hz: resampled shape=(161400, 19)
# fs=200Hz: segments=806
# fs=100Hz: resampled shape=(80700, 19)
# fs=100Hz: segments=402
# fs=50Hz: resampled shape=(40350, 19)
# fs=50Hz: segments=200
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-048\eeg
# [PASS 2] Subject: sub-048, expected total segments=1727
#   load: ADFTD-RS/derivatives\sub-048\eeg\sub-048_task-eyesclosed_eeg.set
# raw shape: (494940, 19)
# fs=200Hz: resampled shape=(197976, 19)
# fs=200Hz: segments=988
# fs=100Hz: resampled shape=(98988, 19)
# fs=100Hz: segments=493
# fs=50Hz: resampled shape=(49494, 19)
# fs=50Hz: segments=246
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-049\eeg
# [PASS 2] Subject: sub-049, expected total segments=1362
#   load: ADFTD-RS/derivatives\sub-049\eeg\sub-049_task-eyesclosed_eeg.set
# raw shape: (390100, 19)
# fs=200Hz: resampled shape=(156040, 19)
# fs=200Hz: segments=779
# fs=100Hz: resampled shape=(78020, 19)
# fs=100Hz: segments=389
# fs=50Hz: resampled shape=(39010, 19)
# fs=50Hz: segments=194
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-050\eeg
# [PASS 2] Subject: sub-050, expected total segments=1426
#   load: ADFTD-RS/derivatives\sub-050\eeg\sub-050_task-eyesclosed_eeg.set
# raw shape: (408820, 19)
# fs=200Hz: resampled shape=(163528, 19)
# fs=200Hz: segments=816
# fs=100Hz: resampled shape=(81764, 19)
# fs=100Hz: segments=407
# fs=50Hz: resampled shape=(40882, 19)
# fs=50Hz: segments=203
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-051\eeg
# [PASS 2] Subject: sub-051, expected total segments=1314
#   load: ADFTD-RS/derivatives\sub-051\eeg\sub-051_task-eyesclosed_eeg.set
# raw shape: (376670, 19)
# fs=200Hz: resampled shape=(150668, 19)
# fs=200Hz: segments=752
# fs=100Hz: resampled shape=(75334, 19)
# fs=100Hz: segments=375
# fs=50Hz: resampled shape=(37667, 19)
# fs=50Hz: segments=187
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-052\eeg
# [PASS 2] Subject: sub-052, expected total segments=1327
#   load: ADFTD-RS/derivatives\sub-052\eeg\sub-052_task-eyesclosed_eeg.set
# raw shape: (380050, 19)
# fs=200Hz: resampled shape=(152020, 19)
# fs=200Hz: segments=759
# fs=100Hz: resampled shape=(76010, 19)
# fs=100Hz: segments=379
# fs=50Hz: resampled shape=(38005, 19)
# fs=50Hz: segments=189
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-053\eeg
# [PASS 2] Subject: sub-053, expected total segments=1362
#   load: ADFTD-RS/derivatives\sub-053\eeg\sub-053_task-eyesclosed_eeg.set
# raw shape: (390260, 19)
# fs=200Hz: resampled shape=(156104, 19)
# fs=200Hz: segments=779
# fs=100Hz: resampled shape=(78052, 19)
# fs=100Hz: segments=389
# fs=50Hz: resampled shape=(39026, 19)
# fs=50Hz: segments=194
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-054\eeg
# [PASS 2] Subject: sub-054, expected total segments=1461
#   load: ADFTD-RS/derivatives\sub-054\eeg\sub-054_task-eyesclosed_eeg.set
# raw shape: (418810, 19)
# fs=200Hz: resampled shape=(167524, 19)
# fs=200Hz: segments=836
# fs=100Hz: resampled shape=(83762, 19)
# fs=100Hz: segments=417
# fs=50Hz: resampled shape=(41881, 19)
# fs=50Hz: segments=208
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-055\eeg
# [PASS 2] Subject: sub-055, expected total segments=1421
#   load: ADFTD-RS/derivatives\sub-055\eeg\sub-055_task-eyesclosed_eeg.set
# raw shape: (407300, 19)
# fs=200Hz: resampled shape=(162920, 19)
# fs=200Hz: segments=813
# fs=100Hz: resampled shape=(81460, 19)
# fs=100Hz: segments=406
# fs=50Hz: resampled shape=(40730, 19)
# fs=50Hz: segments=202
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-056\eeg
# [PASS 2] Subject: sub-056, expected total segments=1380
#   load: ADFTD-RS/derivatives\sub-056\eeg\sub-056_task-eyesclosed_eeg.set
# raw shape: (395660, 19)
# fs=200Hz: resampled shape=(158264, 19)
# fs=200Hz: segments=790
# fs=100Hz: resampled shape=(79132, 19)
# fs=100Hz: segments=394
# fs=50Hz: resampled shape=(39566, 19)
# fs=50Hz: segments=196
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-057\eeg
# [PASS 2] Subject: sub-057, expected total segments=1390
#   load: ADFTD-RS/derivatives\sub-057\eeg\sub-057_task-eyesclosed_eeg.set
# raw shape: (398250, 19)
# fs=200Hz: resampled shape=(159300, 19)
# fs=200Hz: segments=795
# fs=100Hz: resampled shape=(79650, 19)
# fs=100Hz: segments=397
# fs=50Hz: resampled shape=(39825, 19)
# fs=50Hz: segments=198
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-058\eeg
# [PASS 2] Subject: sub-058, expected total segments=1320
#   load: ADFTD-RS/derivatives\sub-058\eeg\sub-058_task-eyesclosed_eeg.set
# raw shape: (378390, 19)
# fs=200Hz: resampled shape=(151356, 19)
# fs=200Hz: segments=755
# fs=100Hz: resampled shape=(75678, 19)
# fs=100Hz: segments=377
# fs=50Hz: resampled shape=(37839, 19)
# fs=50Hz: segments=188
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-059\eeg
# [PASS 2] Subject: sub-059, expected total segments=1373
#   load: ADFTD-RS/derivatives\sub-059\eeg\sub-059_task-eyesclosed_eeg.set
# raw shape: (393560, 19)
# fs=200Hz: resampled shape=(157424, 19)
# fs=200Hz: segments=786
# fs=100Hz: resampled shape=(78712, 19)
# fs=100Hz: segments=392
# fs=50Hz: resampled shape=(39356, 19)
# fs=50Hz: segments=195
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-060\eeg
# [PASS 2] Subject: sub-060, expected total segments=1306
#   load: ADFTD-RS/derivatives\sub-060\eeg\sub-060_task-eyesclosed_eeg.set
# raw shape: (374240, 19)
# fs=200Hz: resampled shape=(149696, 19)
# fs=200Hz: segments=747
# fs=100Hz: resampled shape=(74848, 19)
# fs=100Hz: segments=373
# fs=50Hz: resampled shape=(37424, 19)
# fs=50Hz: segments=186
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-061\eeg
# [PASS 2] Subject: sub-061, expected total segments=1401
#   load: ADFTD-RS/derivatives\sub-061\eeg\sub-061_task-eyesclosed_eeg.set
# raw shape: (401640, 19)
# fs=200Hz: resampled shape=(160656, 19)
# fs=200Hz: segments=802
# fs=100Hz: resampled shape=(80328, 19)
# fs=100Hz: segments=400
# fs=50Hz: resampled shape=(40164, 19)
# fs=50Hz: segments=199
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-062\eeg
# [PASS 2] Subject: sub-062, expected total segments=1568
#   load: ADFTD-RS/derivatives\sub-062\eeg\sub-062_task-eyesclosed_eeg.set
# raw shape: (449350, 19)
# fs=200Hz: resampled shape=(179740, 19)
# fs=200Hz: segments=897
# fs=100Hz: resampled shape=(89870, 19)
# fs=100Hz: segments=448
# fs=50Hz: resampled shape=(44935, 19)
# fs=50Hz: segments=223
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-063\eeg
# [PASS 2] Subject: sub-063, expected total segments=1404
#   load: ADFTD-RS/derivatives\sub-063\eeg\sub-063_task-eyesclosed_eeg.set
# raw shape: (402470, 19)
# fs=200Hz: resampled shape=(160988, 19)
# fs=200Hz: segments=803
# fs=100Hz: resampled shape=(80494, 19)
# fs=100Hz: segments=401
# fs=50Hz: resampled shape=(40247, 19)
# fs=50Hz: segments=200
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-064\eeg
# [PASS 2] Subject: sub-064, expected total segments=1481
#   load: ADFTD-RS/derivatives\sub-064\eeg\sub-064_task-eyesclosed_eeg.set
# raw shape: (424050, 19)
# fs=200Hz: resampled shape=(169620, 19)
# fs=200Hz: segments=847
# fs=100Hz: resampled shape=(84810, 19)
# fs=100Hz: segments=423
# fs=50Hz: resampled shape=(42405, 19)
# fs=50Hz: segments=211
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-065\eeg
# [PASS 2] Subject: sub-065, expected total segments=1544
#   load: ADFTD-RS/derivatives\sub-065\eeg\sub-065_task-eyesclosed_eeg.set
# raw shape: (442050, 19)
# fs=200Hz: resampled shape=(176820, 19)
# fs=200Hz: segments=883
# fs=100Hz: resampled shape=(88410, 19)
# fs=100Hz: segments=441
# fs=50Hz: resampled shape=(44205, 19)
# fs=50Hz: segments=220
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-066\eeg
# [PASS 2] Subject: sub-066, expected total segments=957
#   load: ADFTD-RS/derivatives\sub-066\eeg\sub-066_task-eyesclosed_eeg.set
# raw shape: (274880, 19)
# fs=200Hz: resampled shape=(109952, 19)
# fs=200Hz: segments=548
# fs=100Hz: resampled shape=(54976, 19)
# fs=100Hz: segments=273
# fs=50Hz: resampled shape=(27488, 19)
# fs=50Hz: segments=136
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-067\eeg
# [PASS 2] Subject: sub-067, expected total segments=1121
#   load: ADFTD-RS/derivatives\sub-067\eeg\sub-067_task-eyesclosed_eeg.set
# raw shape: (321550, 19)
# fs=200Hz: resampled shape=(128620, 19)
# fs=200Hz: segments=642
# fs=100Hz: resampled shape=(64310, 19)
# fs=100Hz: segments=320
# fs=50Hz: resampled shape=(32155, 19)
# fs=50Hz: segments=159
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-068\eeg
# [PASS 2] Subject: sub-068, expected total segments=999
#   load: ADFTD-RS/derivatives\sub-068\eeg\sub-068_task-eyesclosed_eeg.set
# raw shape: (286550, 19)
# fs=200Hz: resampled shape=(114620, 19)
# fs=200Hz: segments=572
# fs=100Hz: resampled shape=(57310, 19)
# fs=100Hz: segments=285
# fs=50Hz: resampled shape=(28655, 19)
# fs=50Hz: segments=142
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-069\eeg
# [PASS 2] Subject: sub-069, expected total segments=1110
#   load: ADFTD-RS/derivatives\sub-069\eeg\sub-069_task-eyesclosed_eeg.set
# raw shape: (318050, 19)
# fs=200Hz: resampled shape=(127220, 19)
# fs=200Hz: segments=635
# fs=100Hz: resampled shape=(63610, 19)
# fs=100Hz: segments=317
# fs=50Hz: resampled shape=(31805, 19)
# fs=50Hz: segments=158
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-070\eeg
# [PASS 2] Subject: sub-070, expected total segments=834
#   load: ADFTD-RS/derivatives\sub-070\eeg\sub-070_task-eyesclosed_eeg.set
# raw shape: (239550, 19)
# fs=200Hz: resampled shape=(95820, 19)
# fs=200Hz: segments=478
# fs=100Hz: resampled shape=(47910, 19)
# fs=100Hz: segments=238
# fs=50Hz: resampled shape=(23955, 19)
# fs=50Hz: segments=118
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-071\eeg
# [PASS 2] Subject: sub-071, expected total segments=1078
#   load: ADFTD-RS/derivatives\sub-071\eeg\sub-071_task-eyesclosed_eeg.set
# raw shape: (309450, 19)
# fs=200Hz: resampled shape=(123780, 19)
# fs=200Hz: segments=617
# fs=100Hz: resampled shape=(61890, 19)
# fs=100Hz: segments=308
# fs=50Hz: resampled shape=(30945, 19)
# fs=50Hz: segments=153
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-072\eeg
# [PASS 2] Subject: sub-072, expected total segments=1146
#   load: ADFTD-RS/derivatives\sub-072\eeg\sub-072_task-eyesclosed_eeg.set
# raw shape: (328710, 19)
# fs=200Hz: resampled shape=(131484, 19)
# fs=200Hz: segments=656
# fs=100Hz: resampled shape=(65742, 19)
# fs=100Hz: segments=327
# fs=50Hz: resampled shape=(32871, 19)
# fs=50Hz: segments=163
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-073\eeg
# [PASS 2] Subject: sub-073, expected total segments=1491
#   load: ADFTD-RS/derivatives\sub-073\eeg\sub-073_task-eyesclosed_eeg.set
# raw shape: (427290, 19)
# fs=200Hz: resampled shape=(170916, 19)
# fs=200Hz: segments=853
# fs=100Hz: resampled shape=(85458, 19)
# fs=100Hz: segments=426
# fs=50Hz: resampled shape=(42729, 19)
# fs=50Hz: segments=212
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-074\eeg
# [PASS 2] Subject: sub-074, expected total segments=1771
#   load: ADFTD-RS/derivatives\sub-074\eeg\sub-074_task-eyesclosed_eeg.set
# raw shape: (507250, 19)
# fs=200Hz: resampled shape=(202900, 19)
# fs=200Hz: segments=1013
# fs=100Hz: resampled shape=(101450, 19)
# fs=100Hz: segments=506
# fs=50Hz: resampled shape=(50725, 19)
# fs=50Hz: segments=252
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-075\eeg
# [PASS 2] Subject: sub-075, expected total segments=1306
#   load: ADFTD-RS/derivatives\sub-075\eeg\sub-075_task-eyesclosed_eeg.set
# raw shape: (374090, 19)
# fs=200Hz: resampled shape=(149636, 19)
# fs=200Hz: segments=747
# fs=100Hz: resampled shape=(74818, 19)
# fs=100Hz: segments=373
# fs=50Hz: resampled shape=(37409, 19)
# fs=50Hz: segments=186
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-076\eeg
# [PASS 2] Subject: sub-076, expected total segments=1428
#   load: ADFTD-RS/derivatives\sub-076\eeg\sub-076_task-eyesclosed_eeg.set
# raw shape: (409400, 19)
# fs=200Hz: resampled shape=(163760, 19)
# fs=200Hz: segments=817
# fs=100Hz: resampled shape=(81880, 19)
# fs=100Hz: segments=408
# fs=50Hz: resampled shape=(40940, 19)
# fs=50Hz: segments=203
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-077\eeg
# [PASS 2] Subject: sub-077, expected total segments=1219
#   load: ADFTD-RS/derivatives\sub-077\eeg\sub-077_task-eyesclosed_eeg.set
# raw shape: (349570, 19)
# fs=200Hz: resampled shape=(139828, 19)
# fs=200Hz: segments=698
# fs=100Hz: resampled shape=(69914, 19)
# fs=100Hz: segments=348
# fs=50Hz: resampled shape=(34957, 19)
# fs=50Hz: segments=173
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-078\eeg
# [PASS 2] Subject: sub-078, expected total segments=1519
#   load: ADFTD-RS/derivatives\sub-078\eeg\sub-078_task-eyesclosed_eeg.set
# raw shape: (435450, 19)
# fs=200Hz: resampled shape=(174180, 19)
# fs=200Hz: segments=869
# fs=100Hz: resampled shape=(87090, 19)
# fs=100Hz: segments=434
# fs=50Hz: resampled shape=(43545, 19)
# fs=50Hz: segments=216
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-079\eeg
# [PASS 2] Subject: sub-079, expected total segments=1425
#   load: ADFTD-RS/derivatives\sub-079\eeg\sub-079_task-eyesclosed_eeg.set
# raw shape: (408340, 19)
# fs=200Hz: resampled shape=(163336, 19)
# fs=200Hz: segments=815
# fs=100Hz: resampled shape=(81668, 19)
# fs=100Hz: segments=407
# fs=50Hz: resampled shape=(40834, 19)
# fs=50Hz: segments=203
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-080\eeg
# [PASS 2] Subject: sub-080, expected total segments=1597
#   load: ADFTD-RS/derivatives\sub-080\eeg\sub-080_task-eyesclosed_eeg.set
# raw shape: (457570, 19)
# fs=200Hz: resampled shape=(183028, 19)
# fs=200Hz: segments=914
# fs=100Hz: resampled shape=(91514, 19)
# fs=100Hz: segments=456
# fs=50Hz: resampled shape=(45757, 19)
# fs=50Hz: segments=227
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-081\eeg
# [PASS 2] Subject: sub-081, expected total segments=1439
#   load: ADFTD-RS/derivatives\sub-081\eeg\sub-081_task-eyesclosed_eeg.set
# raw shape: (412240, 19)
# fs=200Hz: resampled shape=(164896, 19)
# fs=200Hz: segments=823
# fs=100Hz: resampled shape=(82448, 19)
# fs=100Hz: segments=411
# fs=50Hz: resampled shape=(41224, 19)
# fs=50Hz: segments=205
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-082\eeg
# [PASS 2] Subject: sub-082, expected total segments=1356
#   load: ADFTD-RS/derivatives\sub-082\eeg\sub-082_task-eyesclosed_eeg.set
# raw shape: (388800, 19)
# fs=200Hz: resampled shape=(155520, 19)
# fs=200Hz: segments=776
# fs=100Hz: resampled shape=(77760, 19)
# fs=100Hz: segments=387
# fs=50Hz: resampled shape=(38880, 19)
# fs=50Hz: segments=193
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-083\eeg
# [PASS 2] Subject: sub-083, expected total segments=1594
#   load: ADFTD-RS/derivatives\sub-083\eeg\sub-083_task-eyesclosed_eeg.set
# raw shape: (456600, 19)
# fs=200Hz: resampled shape=(182640, 19)
# fs=200Hz: segments=912
# fs=100Hz: resampled shape=(91320, 19)
# fs=100Hz: segments=455
# fs=50Hz: resampled shape=(45660, 19)
# fs=50Hz: segments=227
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-084\eeg
# [PASS 2] Subject: sub-084, expected total segments=1138
#   load: ADFTD-RS/derivatives\sub-084\eeg\sub-084_task-eyesclosed_eeg.set
# raw shape: (326050, 19)
# fs=200Hz: resampled shape=(130420, 19)
# fs=200Hz: segments=651
# fs=100Hz: resampled shape=(65210, 19)
# fs=100Hz: segments=325
# fs=50Hz: resampled shape=(32605, 19)
# fs=50Hz: segments=162
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-085\eeg
# [PASS 2] Subject: sub-085, expected total segments=977
#   load: ADFTD-RS/derivatives\sub-085\eeg\sub-085_task-eyesclosed_eeg.set
# raw shape: (280030, 19)
# fs=200Hz: resampled shape=(112012, 19)
# fs=200Hz: segments=559
# fs=100Hz: resampled shape=(56006, 19)
# fs=100Hz: segments=279
# fs=50Hz: resampled shape=(28003, 19)
# fs=50Hz: segments=139
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-086\eeg
# [PASS 2] Subject: sub-086, expected total segments=1008
#   load: ADFTD-RS/derivatives\sub-086\eeg\sub-086_task-eyesclosed_eeg.set
# raw shape: (289400, 19)
# fs=200Hz: resampled shape=(115760, 19)
# fs=200Hz: segments=577
# fs=100Hz: resampled shape=(57880, 19)
# fs=100Hz: segments=288
# fs=50Hz: resampled shape=(28940, 19)
# fs=50Hz: segments=143
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-087\eeg
# [PASS 2] Subject: sub-087, expected total segments=1050
#   load: ADFTD-RS/derivatives\sub-087\eeg\sub-087_task-eyesclosed_eeg.set
# raw shape: (301380, 19)
# fs=200Hz: resampled shape=(120552, 19)
# fs=200Hz: segments=601
# fs=100Hz: resampled shape=(60276, 19)
# fs=100Hz: segments=300
# fs=50Hz: resampled shape=(30138, 19)
# fs=50Hz: segments=149
# -------------------------------------
#
# ADFTD-RS/derivatives\sub-088\eeg
# [PASS 2] Subject: sub-088, expected total segments=1369
#   load: ADFTD-RS/derivatives\sub-088\eeg\sub-088_task-eyesclosed_eeg.set
# raw shape: (392350, 19)
# fs=200Hz: resampled shape=(156940, 19)
# fs=200Hz: segments=783
# fs=100Hz: resampled shape=(78470, 19)
# fs=100Hz: segments=391
# fs=50Hz: resampled shape=(39235, 19)
# fs=50Hz: segments=195
# -------------------------------------
#
# DONE: cur = 121825  expected N_total = 121825
# Total hours across all subjects: 19.40 hours
# Saved meta: Processed\L400\ADFTD-RS\meta.json

# %% [markdown]
# ## Load and check the processed data

# %%
import json
import numpy as np

# load meta information
meta_path = meta_path  # if you already have meta_path in current notebook
with open(meta_path, "r") as f:
    meta = json.load(f)

N = meta["N"]
T = meta["T"]          # SEG_LEN
C = meta["C"]
X_path = meta["X_path"]
y_path = meta["y_path"]

print("Meta:")
print("  N =", N)
print("  T =", T)
print("  C =", C)
print("  X_path =", X_path)
print("  y_path =", y_path)
print("-------------------------------------")

# open memmap
X_mm = np.memmap(X_path, dtype='float32', mode='r', shape=(N, T, C))
y_mm = np.memmap(y_path, dtype='float32', mode='r', shape=(N, 3))

# subject_id is stored in y[:, 1]
subject_ids = np.unique(y_mm[:, 1]).astype(int)

for sid in sorted(subject_ids):
    # find all indices for this subject
    idx = np.where(y_mm[:, 1] == sid)[0]

    # compute shapes logically (do not load all X into memory)
    n_seg = len(idx)
    x_shape = (n_seg, T, C)    # logical X shape for this subject
    y_shape = (n_seg, 3)       # logical y shape for this subject

    # get sampling rates for all segments of this subject
    fs_subject = y_mm[idx, 2]  # shape (n_seg,)


    print(f"Subject ID {sid:03d}: X shape={x_shape}, y shape={y_shape}")

# option: delete memmap views
del X_mm, y_mm
# Out:
# Meta:
#   N = 121825
#   T = 400
#   C = 19
#   X_path = Processed\L400\ADFTD-RS\X.dat
#   y_path = Processed\L400\ADFTD-RS\y.dat
# -------------------------------------
# Subject ID 001: X shape=(1044, 400, 19), y shape=(1044, 3)
# Subject ID 002: X shape=(1384, 400, 19), y shape=(1384, 3)
# Subject ID 003: X shape=(532, 400, 19), y shape=(532, 3)
# Subject ID 004: X shape=(1232, 400, 19), y shape=(1232, 3)
# Subject ID 005: X shape=(1404, 400, 19), y shape=(1404, 3)
# Subject ID 006: X shape=(1103, 400, 19), y shape=(1103, 3)
# Subject ID 007: X shape=(1337, 400, 19), y shape=(1337, 3)
# Subject ID 008: X shape=(1384, 400, 19), y shape=(1384, 3)
# Subject ID 009: X shape=(1068, 400, 19), y shape=(1068, 3)
# Subject ID 010: X shape=(2238, 400, 19), y shape=(2238, 3)
# Subject ID 011: X shape=(1342, 400, 19), y shape=(1342, 3)
# Subject ID 012: X shape=(1541, 400, 19), y shape=(1541, 3)
# Subject ID 013: X shape=(1463, 400, 19), y shape=(1463, 3)
# Subject ID 014: X shape=(1631, 400, 19), y shape=(1631, 3)
# Subject ID 015: X shape=(1573, 400, 19), y shape=(1573, 3)
# Subject ID 016: X shape=(1698, 400, 19), y shape=(1698, 3)
# Subject ID 017: X shape=(1471, 400, 19), y shape=(1471, 3)
# Subject ID 018: X shape=(1475, 400, 19), y shape=(1475, 3)
# Subject ID 019: X shape=(1603, 400, 19), y shape=(1603, 3)
# Subject ID 020: X shape=(1517, 400, 19), y shape=(1517, 3)
# Subject ID 021: X shape=(1607, 400, 19), y shape=(1607, 3)
# Subject ID 022: X shape=(1433, 400, 19), y shape=(1433, 3)
# Subject ID 023: X shape=(1456, 400, 19), y shape=(1456, 3)
# Subject ID 024: X shape=(1324, 400, 19), y shape=(1324, 3)
# Subject ID 025: X shape=(1194, 400, 19), y shape=(1194, 3)
# Subject ID 026: X shape=(1568, 400, 19), y shape=(1568, 3)
# Subject ID 027: X shape=(1442, 400, 19), y shape=(1442, 3)
# Subject ID 028: X shape=(1428, 400, 19), y shape=(1428, 3)
# Subject ID 029: X shape=(1285, 400, 19), y shape=(1285, 3)
# Subject ID 030: X shape=(966, 400, 19), y shape=(966, 3)
# Subject ID 031: X shape=(2009, 400, 19), y shape=(2009, 3)
# Subject ID 032: X shape=(1391, 400, 19), y shape=(1391, 3)
# Subject ID 033: X shape=(1230, 400, 19), y shape=(1230, 3)
# Subject ID 034: X shape=(1692, 400, 19), y shape=(1692, 3)
# Subject ID 035: X shape=(1293, 400, 19), y shape=(1293, 3)
# Subject ID 036: X shape=(1468, 400, 19), y shape=(1468, 3)
# Subject ID 037: X shape=(1356, 400, 19), y shape=(1356, 3)
# Subject ID 038: X shape=(1555, 400, 19), y shape=(1555, 3)
# Subject ID 039: X shape=(1484, 400, 19), y shape=(1484, 3)
# Subject ID 040: X shape=(1685, 400, 19), y shape=(1685, 3)
# Subject ID 041: X shape=(1547, 400, 19), y shape=(1547, 3)
# Subject ID 042: X shape=(1681, 400, 19), y shape=(1681, 3)
# Subject ID 043: X shape=(1447, 400, 19), y shape=(1447, 3)
# Subject ID 044: X shape=(1538, 400, 19), y shape=(1538, 3)
# Subject ID 045: X shape=(1485, 400, 19), y shape=(1485, 3)
# Subject ID 046: X shape=(1314, 400, 19), y shape=(1314, 3)
# Subject ID 047: X shape=(1408, 400, 19), y shape=(1408, 3)
# Subject ID 048: X shape=(1727, 400, 19), y shape=(1727, 3)
# Subject ID 049: X shape=(1362, 400, 19), y shape=(1362, 3)
# Subject ID 050: X shape=(1426, 400, 19), y shape=(1426, 3)
# Subject ID 051: X shape=(1314, 400, 19), y shape=(1314, 3)
# Subject ID 052: X shape=(1327, 400, 19), y shape=(1327, 3)
# Subject ID 053: X shape=(1362, 400, 19), y shape=(1362, 3)
# Subject ID 054: X shape=(1461, 400, 19), y shape=(1461, 3)
# Subject ID 055: X shape=(1421, 400, 19), y shape=(1421, 3)
# Subject ID 056: X shape=(1380, 400, 19), y shape=(1380, 3)
# Subject ID 057: X shape=(1390, 400, 19), y shape=(1390, 3)
# Subject ID 058: X shape=(1320, 400, 19), y shape=(1320, 3)
# Subject ID 059: X shape=(1373, 400, 19), y shape=(1373, 3)
# Subject ID 060: X shape=(1306, 400, 19), y shape=(1306, 3)
# Subject ID 061: X shape=(1401, 400, 19), y shape=(1401, 3)
# Subject ID 062: X shape=(1568, 400, 19), y shape=(1568, 3)
# Subject ID 063: X shape=(1404, 400, 19), y shape=(1404, 3)
# Subject ID 064: X shape=(1481, 400, 19), y shape=(1481, 3)
# Subject ID 065: X shape=(1544, 400, 19), y shape=(1544, 3)
# Subject ID 066: X shape=(957, 400, 19), y shape=(957, 3)
# Subject ID 067: X shape=(1121, 400, 19), y shape=(1121, 3)
# Subject ID 068: X shape=(999, 400, 19), y shape=(999, 3)
# Subject ID 069: X shape=(1110, 400, 19), y shape=(1110, 3)
# Subject ID 070: X shape=(834, 400, 19), y shape=(834, 3)
# Subject ID 071: X shape=(1078, 400, 19), y shape=(1078, 3)
# Subject ID 072: X shape=(1146, 400, 19), y shape=(1146, 3)
# Subject ID 073: X shape=(1491, 400, 19), y shape=(1491, 3)
# Subject ID 074: X shape=(1771, 400, 19), y shape=(1771, 3)
# Subject ID 075: X shape=(1306, 400, 19), y shape=(1306, 3)
# Subject ID 076: X shape=(1428, 400, 19), y shape=(1428, 3)
# Subject ID 077: X shape=(1219, 400, 19), y shape=(1219, 3)
# Subject ID 078: X shape=(1519, 400, 19), y shape=(1519, 3)
# Subject ID 079: X shape=(1425, 400, 19), y shape=(1425, 3)
# Subject ID 080: X shape=(1597, 400, 19), y shape=(1597, 3)
# Subject ID 081: X shape=(1439, 400, 19), y shape=(1439, 3)
# Subject ID 082: X shape=(1356, 400, 19), y shape=(1356, 3)
# Subject ID 083: X shape=(1594, 400, 19), y shape=(1594, 3)
# Subject ID 084: X shape=(1138, 400, 19), y shape=(1138, 3)
# Subject ID 085: X shape=(977, 400, 19), y shape=(977, 3)
# Subject ID 086: X shape=(1008, 400, 19), y shape=(1008, 3)
# Subject ID 087: X shape=(1050, 400, 19), y shape=(1050, 3)
# Subject ID 088: X shape=(1369, 400, 19), y shape=(1369, 3)
